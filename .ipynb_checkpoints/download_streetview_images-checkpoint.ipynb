# %%
import pandas as pd
import google_streetview.api
import google_streetview.helpers
import geopandas as gpd 
import pandas as pd
from shapely import ops
import os
import shapely
import numpy as np
import psycopg2
import pandana as pdna
import networkx as nx
import multiprocessing as mp
import matplotlib.pyplot as plt
from geoalchemy2 import Geometry, WKTElement
from sqlalchemy import *
import time
import psycopg2
from shapely.geometry import *
shapely.speedups.enable()
import subprocess
import requests 
import sys,os,os.path

# %matplotlib inline

# %%
import sys,os,os.path
os.environ['HTTP_PROXY']="http://username:password@proxy.toronto.ca:8080"
os.environ['HTTPS_PROXY']="https://username:password@proxy.toronto.ca:8080"
os.environ['http_proxy']="http://username:password@proxy.toronto.ca:8080"
os.environ['https_proxy']="https://username:password@proxy.toronto.ca:8080"
proxies = {'http': 'https://username:password@proxy.toronto.ca:8080'}

# %%
# con = psycopg2.connect(database="walkability", user="postgres", password=1234,
#     host="172.19.118.205",port="5432")
# point = gpd.read_postgis("select * from public.centreline_midpoints", con, crs={'init': 'epsg:4326'})
# point = point.to_crs({'init': 'epsg:4326'})
# point.plot()

# %%
point = pd.read_csv('/media/DATADRIVE/Toronto_Streetscore/toronto/toronto_street_intersections.csv')
point['id'] = point.index

point['location'] = point.latitude.astype(str).str.cat(point.longitude.astype(str), sep=',')
# point
point['image'] =None
# point['image_0'] =None
# point['image_90'] =None
# point['image_180'] =None
# point['image_270'] =None

# %%
point
# Out:
#          latitude  longitude    q-score      id  \
# 0       40.700909 -74.013504  11.062166       0
# 1       40.701000 -74.013878  10.818611       1
# 2       40.701080 -74.012878  12.677955       2
# 3       40.701187 -74.013268  11.417325       3
# 4       40.701244 -74.012115  25.199091       4
# 5       40.701332 -74.012573   9.335472       5
# 6       40.701401 -74.013954  21.422491       6
# 7       40.701462 -74.014297  11.072771       7
# 8       40.701477 -74.011406  21.323076       8
# 9       40.701496 -74.014694   9.223970       9
# 10      40.701530 -74.011810  17.142195      10
# 11      40.701630 -74.010490  18.004122      11
# 12      40.701633 -74.013344  11.630168      12
# 13      40.701645 -74.012650  19.722942      13
# 14      40.701756 -74.013657  21.745884      14
# 15      40.701801 -74.010841  31.937878      15
# 16      40.701805 -74.011185  12.101864      16
# 17      40.701832 -74.014389  33.230228      17
# ...

# %%
import urllib.request
import shutil
import tempfile
import urllib.request
import urllib.parse
import os
key = "&key="+key #got banned after ~100 requests with no key


def GetStreet(i,Id,location,heading=None):
    i=i
    if heading:
        base = "https://maps.googleapis.com/maps/api/streetview?size=1200x800&heading="+str(heading)+"&source=outdoor&fov=120&location="
    else:
        base = "https://maps.googleapis.com/maps/api/streetview?size=1200x800&source=outdoor&fov=120&location="

    MyUrl = base + urllib.parse.quote_plus(location) + key #added url encoding
    
    fi = r"/media/DATADRIVE/walkability/Toronto_Streetscore/nyimages/"+str(i)+".jpg"
    if not os.path.isfile(fi):
        try:
            #print(MyUrl)
            with requests.get(MyUrl, stream=True) as response:
                data = response.raw.read()
                if int(response.headers['content-length']) >100:
                    print(fi)
                    output = open(fi,"wb")
                    output.write(data)
                    output.close()
                else:
                    fi = None
        except:
            fi = "Failed"
            pass
    return fi

# %%
c = 0

for i, row in point.sample(frac=.3).iterrows():
    fi = GetStreet(i,row.id,row.location,None)
    point.loc[i,'image'] = fi
#     fi = GetStreet(i,row.cid, row.location,0)
#     point.loc[i,'image_0'] = fi
#     fi = GetStreet(i,row.cid, row.location,180)
#     point.loc[i,'image_180'] = fi
#     fi = GetStreet(i,row.cid, row.location,270)
#     point.loc[i,'image_270'] = fi
    c+=1
    print(c-point.id.count())
    if c >= 25000:
        break
# Out:
# /media/DATADRIVE/walkability/Toronto_Streetscore/nyimages/61738.jpg
# -322385
# /media/DATADRIVE/walkability/Toronto_Streetscore/nyimages/133674.jpg
# -322384
# /media/DATADRIVE/walkability/Toronto_Streetscore/nyimages/212404.jpg
# -322383
# /media/DATADRIVE/walkability/Toronto_Streetscore/nyimages/106672.jpg
# -322382
# /media/DATADRIVE/walkability/Toronto_Streetscore/nyimages/272006.jpg
# -322381
# /media/DATADRIVE/walkability/Toronto_Streetscore/nyimages/240181.jpg
# -322380
# /media/DATADRIVE/walkability/Toronto_Streetscore/nyimages/178568.jpg
# -322379
# -322378
# /media/DATADRIVE/walkability/Toronto_Streetscore/nyimages/45370.jpg
# -322377
# /media/DATADRIVE/walkability/Toronto_Streetscore/nyimages/255901.jpg
# -322376
# /media/DATADRIVE/walkability/Toronto_Streetscore/nyimages/49234.jpg
# -322375
# /media/DATADRIVE/walkability/Toronto_Streetscore/nyimages/271054.jpg
# -322374
# /media/DATADRIVE/walkability/Toronto_Streetscore/nyimages/297322.jpg
# -322373
# ...

# %%
c = 0

for i, row in point.iterrows():
    if not row.image_0:
        fi = GetStreet(i, row.location,90)
        point.loc[i,'image_90'] = fi
        fi = GetStreet(i, row.location,0)
        point.loc[i,'image_0'] = fi
        fi = GetStreet(i, row.location,180)
        point.loc[i,'image_180'] = fi
        fi = GetStreet(i, row.location,270)
        point.loc[i,'image_270'] = fi
        c+=1
        print(c-point.gid.count())
        if c >= 20000:
            break

# %%
point.to_csv('/media/DATADRIVE/walkability/Toronto_Streetscore/ny_points.csv')

# %%
x,y = row.geom.coords.xy
location

# %%
for i, row in point.iterrows():
    row.geom

# %%
df.tail(4)

# %%
point
